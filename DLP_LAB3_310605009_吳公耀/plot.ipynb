# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('test.csv')

# %%
episode = []
score = []

episode = [i for i in file['iter']]
mean_score = [j for j in file['mean score']]
max_score = [k for k in file['max score']]

# %%
plt.xlabel("episodes")
plt.ylabel("score")
mean = plt.plot(episode,mean_score, label='mean score')
max = plt.plot(episode,max_score, label='max score')
plt.legend(loc='upper left')

plt.show()
